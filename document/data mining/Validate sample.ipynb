# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('validate2.csv',encoding="latin-1")

# %%
datasample =  data.sample(n=80)

# %%
datasample
# Out:
#                           filename                         source category  \
# 364                 visMost232.png                      Visual.ly        I
# 257                     wsj553.png            Wall Street Journal        N
# 281                     wsj459.png            Wall Street Journal        N
# 140           v487_n7407_15_f3.png                         Nature        S
# 113                 visMost374.png                      Visual.ly        I
# 236  economist_daily_chart_392.png                Economist Daily        N
# 369                     vis479.png                      Visual.ly        I
# 152           v487_n7406_13_f2.png                         Nature        S
# 229                       np_7.png                  National Post        N
# 60                    whoJ40_2.png      World Health Organization        G
# 83             v483_n7391_3_f5.png                         Nature        S
# ...

# %%
datasample.to_csv('v2.csv',index=False)

# %%
data = pd.read_csv('validate2.csv',encoding="latin-1")

# %%
datasample =  data.sample(n=50)
